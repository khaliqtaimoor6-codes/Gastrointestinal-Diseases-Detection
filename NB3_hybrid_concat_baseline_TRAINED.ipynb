# %% [markdown]
# # GastroNet — NB3: hybrid_concat baseline (EfficientNet-B4 + ViT-Small, concat fusion)
#
# **Prerequisite**: NB0 (with v2 split) already run on this account.
#
# **What this is, honestly**: this is the concat-fusion **ablation baseline**,
# not the project's proposed contribution. Its job is to give an honest number
# for the simplest possible fusion approach, so that `hybrid_crossattn`
# (NB4/NB5) can later be judged against it fairly. Given how tightly
# `cnn_only_v2` and `vit_only_v2` are expected to cluster around 97-98.5% (see
# the project handoff doc, Sections 1/2/9), this model beating or losing to
# the paper's 98.25% headline is not the point -- what matters is whether
# cross-attention fusion later adds anything *over this baseline*.
#
# **Architecture** (per the locked Option C decision from NB2):
# - CNN branch: EfficientNet-B4, pretrained, classifier head removed, native
#   input **448x448**, produces a 1792-dim feature vector.
# - ViT branch: ViT-Small (`timm`, `vit_small_patch16_224`), pretrained,
#   classification head removed, native input **224x224**, produces a
#   384-dim feature vector.
# - Fusion: the two feature vectors are concatenated (1792+384=2176-dim) and
#   passed through a small classifier head (`Linear(2176,256) -> ReLU ->
#   Dropout(0.3) -> Linear(256,4)`).
# - Each image is resized to BOTH 448 and 224 per sample (two tensors per
#   sample, one per branch) -- neither branch's native resolution is
#   compromised. Augmentation decisions (flip, rotation, color jitter) are
#   applied once per sample and shared across both resized copies, so both
#   branches see consistent augmented views of the same image rather than
#   two independently-randomized versions.
#
# `MODEL_FAMILY = "hybrid_concat_v2"`. Same multi-seed (42, 123, 7), early
# stopping (`PATIENCE=6`), checkpointing, and manifest-logging pattern as NB1
# and NB2.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, sys, json

ACCOUNT_TAG      = "acct_A"
EXPERIMENTS_ROOT = "/content/drive/MyDrive/gastronet_experiments"
NOTEBOOK_NAME    = "NB3_hybrid_concat_baseline"
RAW_DATASET_DIR  = "/content/drive/MyDrive/gastronet_raw_dataset"

MODEL_FAMILY = "hybrid_concat_v2"
SEEDS_TO_RUN = [42, 123, 7]

CLASS_NAMES = ["Diverticulosis", "Neoplasm", "Peritonitis", "Ureters"]
IMG_SIZE_CNN = 448      # EfficientNet-B4's native training size (matches NB1)
IMG_SIZE_VIT = 224      # ViT-Small's native pretrained size (matches NB2)
BATCH_SIZE = 12         # lower than NB1/NB2's 16 -- this model holds two backbones + two
                         # image tensors per sample in memory at once; drop to 8 if you hit OOM
NUM_EPOCHS = 30
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE = 6

SPLIT_JSON_PATH    = os.path.join(EXPERIMENTS_ROOT, "dataset_split_v2.json")
MANIFEST_JSON_PATH = os.path.join(EXPERIMENTS_ROOT, "experiments_manifest.json")

assert os.path.exists(SPLIT_JSON_PATH), (
    "dataset_split_v2.json not found. Run NB0's duplicate-check/v2-split cells first."
)
assert os.path.exists(os.path.join(EXPERIMENTS_ROOT, "checkpoint_utils.py")), (
    "checkpoint_utils.py not found in EXPERIMENTS_ROOT."
)

sys.path.insert(0, EXPERIMENTS_ROOT)
import checkpoint_utils as cku
print("checkpoint_utils imported OK from:", EXPERIMENTS_ROOT)
# Out:
# checkpoint_utils imported OK from: /content/drive/MyDrive/gastronet_experiments

# %% [markdown]
# ### Local dataset copy (same reasoning as NB1/NB2 -- avoids Drive rate-limiting)

# %%
import shutil

LOCAL_DATASET_DIR = "/content/gastro_local_copy"

if not os.path.exists(LOCAL_DATASET_DIR):
    os.makedirs(LOCAL_DATASET_DIR)
    for cls in CLASS_NAMES:
        src_dir = os.path.join(RAW_DATASET_DIR, cls)
        dst_dir = os.path.join(LOCAL_DATASET_DIR, cls)
        os.makedirs(dst_dir, exist_ok=True)
        files = os.listdir(src_dir)
        print(f"Copying class '{cls}': {len(files)} files")
        for i, fname in enumerate(files):
            shutil.copy2(os.path.join(src_dir, fname), os.path.join(dst_dir, fname))
            if (i + 1) % 200 == 0:
                print(f"  [{cls}] copied {i+1}/{len(files)}")
    print("Local copy complete.")
else:
    print("Local copy already exists this session, skipping copy.")
# Out:
# Copying class 'Diverticulosis': 1000 files
#   [Diverticulosis] copied 200/1000
#   [Diverticulosis] copied 400/1000
#   [Diverticulosis] copied 600/1000
#   [Diverticulosis] copied 800/1000
#   [Diverticulosis] copied 1000/1000
# Copying class 'Neoplasm': 1000 files
#   [Neoplasm] copied 200/1000
#   [Neoplasm] copied 400/1000
#   [Neoplasm] copied 600/1000
#   [Neoplasm] copied 800/1000
#   [Neoplasm] copied 1000/1000
# Copying class 'Peritonitis': 1000 files
#   [Peritonitis] copied 200/1000
#   [Peritonitis] copied 400/1000
#   [Peritonitis] copied 600/1000
#   [Peritonitis] copied 800/1000
#   [Peritonitis] copied 1000/1000
# Copying class 'Ureters': 1000 files
#   [Ureters] copied 200/1000
#   [Ureters] copied 400/1000
#   [Ureters] copied 600/1000
#   [Ureters] copied 800/1000
#   [Ureters] copied 1000/1000
# Local copy complete.

# %%
with open(SPLIT_JSON_PATH) as f:
    split_payload = json.load(f)

SPLIT_HASH = split_payload["split_hash"]
split = split_payload["split"]
assert split_payload["class_names"] == CLASS_NAMES, "Class name mismatch with locked split!"

print("Loaded split_hash (v2):", SPLIT_HASH)
for k in ["train", "val", "test"]:
    print(f"  {k}: {len(split[k])} images")

def remap_to_local(entries):
    return [(p.replace(RAW_DATASET_DIR, LOCAL_DATASET_DIR), cls) for p, cls in entries]

split = {k: remap_to_local(v) for k, v in split.items()}
print("Paths remapped to local copy, e.g.:", split["train"][0][0])
# Out:
# Loaded split_hash (v2): d6e80caa29bff18856ae93ea635b4650
#   train: 3198 images
#   val: 400 images
#   test: 400 images
# Paths remapped to local copy, e.g.: /content/gastro_local_copy/Diverticulosis/08648b7f-37b9-406e-b1c3-03683c3222af.jpg

# %%
import torch
import random
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
from PIL import Image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

class_to_idx = {c: i for i, c in enumerate(CLASS_NAMES)}

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

_to_tensor_norm = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

class GastroDualDataset(Dataset):
    '''
    Returns (cnn_tensor, vit_tensor, label) per sample -- one image resized
    two ways, one per branch, per the locked Option C decision (no branch's
    native resolution is compromised). Augmentation decisions (flip,
    rotation, color jitter) are drawn once per sample and applied to BOTH
    resized copies, so the two branches see consistent augmented views of
    the same underlying image rather than two independently-randomized ones.
    '''
    def __init__(self, entries, train_mode):
        self.entries = entries
        self.train_mode = train_mode

    def __len__(self):
        return len(self.entries)

    def __getitem__(self, idx):
        path, cls = self.entries[idx]
        img = Image.open(path).convert("RGB")

        if self.train_mode:
            if random.random() < 0.5:
                img = TF.hflip(img)
            angle = random.uniform(-10, 10)
            img = TF.rotate(img, angle)
            brightness = random.uniform(0.9, 1.1)
            contrast = random.uniform(0.9, 1.1)
            img = TF.adjust_brightness(img, brightness)
            img = TF.adjust_contrast(img, contrast)

        cnn_img = img.resize((IMG_SIZE_CNN, IMG_SIZE_CNN))
        vit_img = img.resize((IMG_SIZE_VIT, IMG_SIZE_VIT))

        cnn_tensor = _to_tensor_norm(cnn_img)
        vit_tensor = _to_tensor_norm(vit_img)
        label = class_to_idx[cls]
        return cnn_tensor, vit_tensor, label


train_ds = GastroDualDataset(split["train"], train_mode=True)
val_ds   = GastroDualDataset(split["val"], train_mode=False)
test_ds  = GastroDualDataset(split["test"], train_mode=False)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

print(f"train={len(train_ds)} val={len(val_ds)} test={len(test_ds)} batches/epoch={len(train_loader)}")
# Out:
# Device: cuda
# train=3198 val=400 test=400 batches/epoch=267

# %%
# !pip install timm --break-system-packages -q

import timm
import torch.nn as nn
from torchvision.models import efficientnet_b4, EfficientNet_B4_Weights


class HybridConcatModel(nn.Module):
    def __init__(self, num_classes=len(CLASS_NAMES)):
        super().__init__()

        # CNN branch: EfficientNet-B4, classifier removed, keep feature extractor + pooling.
        cnn_weights = EfficientNet_B4_Weights.IMAGENET1K_V1
        cnn = efficientnet_b4(weights=cnn_weights)
        self.cnn_features = cnn.features
        self.cnn_pool = cnn.avgpool
        cnn_feature_dim = cnn.classifier[1].in_features   # 1792 for EfficientNet-B4

        # ViT branch: ViT-Small, classification head removed via num_classes=0
        # (timm returns the pooled feature vector directly in this mode).
        self.vit = timm.create_model("vit_small_patch16_224", pretrained=True, num_classes=0)
        vit_feature_dim = self.vit.num_features            # 384 for vit_small

        fused_dim = cnn_feature_dim + vit_feature_dim
        self.classifier = nn.Sequential(
            nn.Linear(fused_dim, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes),
        )

        self.cnn_feature_dim = cnn_feature_dim
        self.vit_feature_dim = vit_feature_dim

    def forward(self, cnn_img, vit_img):
        cnn_feat = self.cnn_features(cnn_img)
        cnn_feat = self.cnn_pool(cnn_feat)
        cnn_feat = torch.flatten(cnn_feat, 1)          # (B, 1792)

        vit_feat = self.vit(vit_img)                    # (B, 384)

        fused = torch.cat([cnn_feat, vit_feat], dim=1)  # (B, 2176)
        return self.classifier(fused)


def build_hybrid_concat_model(num_classes=len(CLASS_NAMES)):
    return HybridConcatModel(num_classes)

_probe = build_hybrid_concat_model()
print(f"CNN branch feature dim: {_probe.cnn_feature_dim}")
print(f"ViT branch feature dim: {_probe.vit_feature_dim}")
print(f"Total params: {sum(p.numel() for p in _probe.parameters()):,}")
del _probe
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-23ab8bcd.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-23ab8bcd.pth
# 100%|██████████| 74.5M/74.5M [00:00<00:00, 177MB/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 88.2MB
# model.safetensors: downloading bytes:           |  0.00B
# CNN branch feature dim: 1792
# ViT branch feature dim: 384
# Total params: 39,772,620

# %%
import time

def run_epoch(model, optimizer, scaler, criterion, loader, train_mode, print_every=20):
    model.train() if train_mode else model.eval()
    total_loss, correct, total = 0.0, 0, 0
    start_time = time.time()
    last_print_time = start_time

    with torch.set_grad_enabled(train_mode):
        for batch_idx, (cnn_imgs, vit_imgs, labels) in enumerate(loader):
            cnn_imgs = cnn_imgs.to(device, non_blocking=True)
            vit_imgs = vit_imgs.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            if train_mode:
                optimizer.zero_grad()

            with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
                outputs = model(cnn_imgs, vit_imgs)
                loss = criterion(outputs, labels)

            if train_mode:
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

            total_loss += loss.item() * cnn_imgs.size(0)
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total += cnn_imgs.size(0)

            if (batch_idx + 1) % print_every == 0:
                now = time.time()
                chunk_time = now - last_print_time
                last_print_time = now
                running_acc = correct / total
                mode_str = "train" if train_mode else "val"
                print(f"    [{mode_str}] batch {batch_idx+1}/{len(loader)} "
                      f"| running_acc={running_acc:.4f} "
                      f"| this_chunk={chunk_time:.1f}s | total_elapsed={now - start_time:.1f}s")

    return total_loss / total, correct / total

# %%
all_seed_results = {}

for SEED in SEEDS_TO_RUN:
    seed_exp_dir = cku.get_experiment_dir(EXPERIMENTS_ROOT, MODEL_FAMILY, SEED)

    if os.path.exists(os.path.join(seed_exp_dir, "results.json")):
        print(f"Seed {SEED} already has results.json, skipping.")
        with open(os.path.join(seed_exp_dir, "results.json")) as f:
            all_seed_results[SEED] = json.load(f)
        continue

    print(f"\n{'='*60}\nStarting SEED={SEED}\n{'='*60}")

    torch.manual_seed(SEED)
    model = build_hybrid_concat_model().to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)
    scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))
    criterion = nn.CrossEntropyLoss()

    start_epoch, best_val_acc, history = cku.resume_or_start(
        seed_exp_dir, model, optimizer, scheduler, scaler, map_location=device
    )
    cku.log_run_event(MANIFEST_JSON_PATH, MODEL_FAMILY, SEED, ACCOUNT_TAG, NOTEBOOK_NAME,
                       status="resumed" if start_epoch > 0 else "started",
                       best_val_acc=best_val_acc, drive_path=seed_exp_dir)

    epochs_without_improvement = 0

    try:
        for epoch in range(start_epoch, NUM_EPOCHS):
            train_loss, train_acc = run_epoch(model, optimizer, scaler, criterion, train_loader, train_mode=True)
            val_loss, val_acc = run_epoch(model, optimizer, scaler, criterion, val_loader, train_mode=False)
            scheduler.step()

            history["train_loss"].append(train_loss)
            history["val_loss"].append(val_loss)
            history["val_acc"].append(val_acc)
            print(f"[seed {SEED}] Epoch {epoch+1}/{NUM_EPOCHS} | "
                  f"train_loss={train_loss:.4f} train_acc={train_acc:.4f} | "
                  f"val_loss={val_loss:.4f} val_acc={val_acc:.4f}")

            cku.save_latest(seed_exp_dir, epoch, model, optimizer, scheduler, scaler, best_val_acc, history)

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                epochs_without_improvement = 0
                config = {
                    "model_family": MODEL_FAMILY, "seed": SEED, "split_hash": SPLIT_HASH,
                    "account_tag": ACCOUNT_TAG, "notebook_name": NOTEBOOK_NAME,
                    "img_size_cnn": IMG_SIZE_CNN, "img_size_vit": IMG_SIZE_VIT,
                    "batch_size": BATCH_SIZE, "learning_rate": LEARNING_RATE,
                    "class_names": CLASS_NAMES, "fusion_type": "concat",
                }
                cku.save_best(seed_exp_dir, model, epoch, best_val_acc, config)
                cku.save_config(seed_exp_dir, config)
                print(f"  -> new best_val_acc={best_val_acc:.4f}, saved best.pt")
            else:
                epochs_without_improvement += 1
                print(f"  -> no improvement for {epochs_without_improvement}/{PATIENCE} epochs")
                if epochs_without_improvement >= PATIENCE:
                    print(f"Stopping early for seed {SEED}: no improvement for {PATIENCE} epochs.")
                    cku.save_history(seed_exp_dir, history)
                    break

            cku.save_history(seed_exp_dir, history)

    except KeyboardInterrupt:
        cku.log_run_event(MANIFEST_JSON_PATH, MODEL_FAMILY, SEED, ACCOUNT_TAG, NOTEBOOK_NAME,
                           status="interrupted", best_val_acc=best_val_acc, drive_path=seed_exp_dir,
                           note="Manually interrupted -- latest.pt has current state, safe to resume.")
        print(f"Interrupted during seed {SEED}. Re-run this cell to resume from the last completed epoch.")
        break

    # Test-set evaluation for this seed
    best_ckpt = cku.load_best(seed_exp_dir, map_location=device)
    cku.assert_split_hash_matches(best_ckpt["config"], SPLIT_HASH)
    eval_model = build_hybrid_concat_model().to(device)
    eval_model.load_state_dict(best_ckpt["model_state_dict"])
    eval_model.eval()

    correct, total, preds_all, labels_all = 0, 0, [], []
    with torch.no_grad():
        for cnn_imgs, vit_imgs, labels in test_loader:
            cnn_imgs, vit_imgs, labels = cnn_imgs.to(device), vit_imgs.to(device), labels.to(device)
            preds = eval_model(cnn_imgs, vit_imgs).argmax(dim=1)
            correct += (preds == labels).sum().item()
            total += cnn_imgs.size(0)
            preds_all.extend(preds.cpu().tolist())
            labels_all.extend(labels.cpu().tolist())

    test_acc = correct / total
    results = {
        "model_family": MODEL_FAMILY, "seed": SEED, "split_hash": SPLIT_HASH,
        "account_tag": ACCOUNT_TAG, "best_epoch": best_ckpt["epoch"],
        "best_val_acc": best_ckpt["best_val_acc"], "test_accuracy": test_acc,
        "predictions": preds_all, "labels": labels_all, "class_names": CLASS_NAMES,
    }
    cku.save_results(seed_exp_dir, results)
    all_seed_results[SEED] = results

    cku.log_run_event(MANIFEST_JSON_PATH, MODEL_FAMILY, SEED, ACCOUNT_TAG, NOTEBOOK_NAME,
                       status="completed", best_val_acc=best_val_acc, drive_path=seed_exp_dir)

    cku.finalize_experiment(seed_exp_dir)
    print(f"Seed {SEED} done. test_acc={test_acc:.4f}. latest.pt cleaned up.\n")

print("\nSeeds completed this run:")
for s, r in all_seed_results.items():
    print(f"  seed {s}: test_accuracy={r['test_accuracy']:.4f}, best_val_acc={r['best_val_acc']:.4f}")
# Out:
# ============================================================
# Starting SEED=42
# ============================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /tmp/ipykernel_1243/2318164100.py:18: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))
# [/content/drive/MyDrive/gastronet_experiments/hybrid_concat_v2/seed_42] No latest.pt found -- starting fresh at epoch 0.
#     [train] batch 20/267 | running_acc=0.5375 | this_chunk=25.2s | total_elapsed=25.2s
#     [train] batch 40/267 | running_acc=0.6625 | this_chunk=10.0s | total_elapsed=35.2s
#     [train] batch 60/267 | running_acc=0.7319 | this_chunk=8.7s | total_elapsed=43.8s
#     [train] batch 80/267 | running_acc=0.7667 | this_chunk=9.6s | total_elapsed=53.4s
#     [train] batch 100/267 | running_acc=0.8008 | this_chunk=11.4s | total_elapsed=64.8s
#     [train] batch 120/267 | running_acc=0.8222 | this_chunk=8.2s | total_elapsed=73.0s
#     [train] batch 140/267 | running_acc=0.8357 | this_chunk=9.7s | total_elapsed=82.6s
#     [train] batch 160/267 | running_acc=0.8479 | this_chunk=10.2s | total_elapsed=92.8s
#     [train] batch 180/267 | running_acc=0.8593 | this_chunk=8.2s | total_elapsed=101.0s
#     [train] batch 200/267 | running_acc=0.8700 | this_chunk=9.9s | total_elapsed=110.9s
#     [train] batch 220/267 | running_acc=0.8750 | this_chunk=10.3s | total_elapsed=121.3s
#     [train] batch 240/267 | running_acc=0.8809 | this_chunk=8.0s | total_elapsed=129.3s
#     [train] batch 260/267 | running_acc=0.8853 | this_chunk=10.1s | total_elapsed=139.4s
#     [val] batch 20/34 | running_acc=0.9625 | this_chunk=5.4s | total_elapsed=5.4s
# [seed 42] Epoch 1/30 | train_loss=0.3089 train_acc=0.8862 | val_loss=0.1553 val_acc=0.9575
#   -> new best_val_acc=0.9575, saved best.pt
#     [train] batch 20/267 | running_acc=0.9583 | this_chunk=12.4s | total_elapsed=12.4s
#     [train] batch 40/267 | running_acc=0.9583 | this_chunk=10.6s | total_elapsed=23.0s
#     [train] batch 60/267 | running_acc=0.9611 | this_chunk=9.4s | total_elapsed=32.4s
#     [train] batch 80/267 | running_acc=0.9625 | this_chunk=8.9s | total_elapsed=41.3s
#     [train] batch 100/267 | running_acc=0.9642 | this_chunk=10.1s | total_elapsed=51.4s
#     [train] batch 120/267 | running_acc=0.9611 | this_chunk=9.2s | total_elapsed=60.6s
#     [train] batch 140/267 | running_acc=0.9613 | this_chunk=10.0s | total_elapsed=70.6s
#     [train] batch 160/267 | running_acc=0.9599 | this_chunk=9.9s | total_elapsed=80.5s
#     [train] batch 180/267 | running_acc=0.9602 | this_chunk=9.7s | total_elapsed=90.2s
#     [train] batch 200/267 | running_acc=0.9600 | this_chunk=9.4s | total_elapsed=99.5s
#     [train] batch 220/267 | running_acc=0.9621 | this_chunk=10.3s | total_elapsed=109.8s
#     [train] batch 240/267 | running_acc=0.9618 | this_chunk=9.6s | total_elapsed=119.4s
#     [train] batch 260/267 | running_acc=0.9612 | this_chunk=9.4s | total_elapsed=128.8s
#     [val] batch 20/34 | running_acc=0.9750 | this_chunk=6.3s | total_elapsed=6.3s
# [seed 42] Epoch 2/30 | train_loss=0.1093 train_acc=0.9619 | val_loss=0.0969 val_acc=0.9675
#   -> new best_val_acc=0.9675, saved best.pt
#     [train] batch 20/267 | running_acc=0.9750 | this_chunk=11.4s | total_elapsed=11.4s
#     [train] batch 40/267 | running_acc=0.9812 | this_chunk=13.2s | total_elapsed=24.6s
#     [train] batch 60/267 | running_acc=0.9819 | this_chunk=12.9s | total_elapsed=37.5s
#     [train] batch 80/267 | running_acc=0.9802 | this_chunk=12.0s | total_elapsed=49.6s
#     [train] batch 100/267 | running_acc=0.9825 | this_chunk=9.3s | total_elapsed=58.8s
#     [train] batch 120/267 | running_acc=0.9799 | this_chunk=11.9s | total_elapsed=70.7s
#     [train] batch 140/267 | running_acc=0.9762 | this_chunk=11.4s | total_elapsed=82.1s
#     [train] batch 160/267 | running_acc=0.9760 | this_chunk=9.9s | total_elapsed=92.0s
#     [train] batch 180/267 | running_acc=0.9769 | this_chunk=8.3s | total_elapsed=100.3s
#     [train] batch 200/267 | running_acc=0.9788 | this_chunk=9.9s | total_elapsed=110.2s
#     [train] batch 220/267 | running_acc=0.9777 | this_chunk=9.5s | total_elapsed=119.7s
#     [train] batch 240/267 | running_acc=0.9774 | this_chunk=8.9s | total_elapsed=128.6s
#     [train] batch 260/267 | running_acc=0.9779 | this_chunk=10.4s | total_elapsed=139.1s
#     [val] batch 20/34 | running_acc=0.9750 | this_chunk=5.9s | total_elapsed=5.9s
# [seed 42] Epoch 3/30 | train_loss=0.0702 train_acc=0.9778 | val_loss=0.1002 val_acc=0.9725
#   -> new best_val_acc=0.9725, saved best.pt
#     [train] batch 20/267 | running_acc=0.9833 | this_chunk=11.0s | total_elapsed=11.0s
#     [train] batch 40/267 | running_acc=0.9833 | this_chunk=13.3s | total_elapsed=24.3s
#     [train] batch 60/267 | running_acc=0.9806 | this_chunk=13.4s | total_elapsed=37.7s
#     [train] batch 80/267 | running_acc=0.9844 | this_chunk=10.7s | total_elapsed=48.4s
#     [train] batch 100/267 | running_acc=0.9850 | this_chunk=10.7s | total_elapsed=59.1s
#     [train] batch 120/267 | running_acc=0.9854 | this_chunk=11.7s | total_elapsed=70.8s
#     [train] batch 140/267 | running_acc=0.9839 | this_chunk=11.9s | total_elapsed=82.7s
#     [train] batch 160/267 | running_acc=0.9833 | this_chunk=8.8s | total_elapsed=91.5s
#     [train] batch 180/267 | running_acc=0.9833 | this_chunk=9.9s | total_elapsed=101.4s
#     [train] batch 200/267 | running_acc=0.9821 | this_chunk=10.2s | total_elapsed=111.6s
#     [train] batch 220/267 | running_acc=0.9818 | this_chunk=8.6s | total_elapsed=120.2s
#     [train] batch 240/267 | running_acc=0.9809 | this_chunk=10.3s | total_elapsed=130.4s
#     [train] batch 260/267 | running_acc=0.9821 | this_chunk=10.1s | total_elapsed=140.6s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=5.2s | total_elapsed=5.2s
# [seed 42] Epoch 4/30 | train_loss=0.0534 train_acc=0.9822 | val_loss=0.0569 val_acc=0.9775
#   -> new best_val_acc=0.9775, saved best.pt
#     [train] batch 20/267 | running_acc=0.9833 | this_chunk=9.0s | total_elapsed=9.0s
#     [train] batch 40/267 | running_acc=0.9792 | this_chunk=12.5s | total_elapsed=21.5s
#     [train] batch 60/267 | running_acc=0.9806 | this_chunk=13.4s | total_elapsed=34.9s
#     [train] batch 80/267 | running_acc=0.9833 | this_chunk=12.8s | total_elapsed=47.7s
#     [train] batch 100/267 | running_acc=0.9850 | this_chunk=11.1s | total_elapsed=58.8s
#     [train] batch 120/267 | running_acc=0.9833 | this_chunk=8.5s | total_elapsed=67.3s
#     [train] batch 140/267 | running_acc=0.9839 | this_chunk=12.7s | total_elapsed=80.0s
#     [train] batch 160/267 | running_acc=0.9854 | this_chunk=10.6s | total_elapsed=90.6s
#     [train] batch 180/267 | running_acc=0.9861 | this_chunk=8.6s | total_elapsed=99.3s
#     [train] batch 200/267 | running_acc=0.9850 | this_chunk=9.5s | total_elapsed=108.8s
#     [train] batch 220/267 | running_acc=0.9845 | this_chunk=10.2s | total_elapsed=118.9s
#     [train] batch 240/267 | running_acc=0.9854 | this_chunk=8.4s | total_elapsed=127.3s
#     [train] batch 260/267 | running_acc=0.9856 | this_chunk=9.7s | total_elapsed=137.0s
#     [val] batch 20/34 | running_acc=0.9792 | this_chunk=6.8s | total_elapsed=6.8s
# [seed 42] Epoch 5/30 | train_loss=0.0402 train_acc=0.9859 | val_loss=0.0566 val_acc=0.9775
#   -> no improvement for 1/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=11.3s | total_elapsed=11.3s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=13.0s | total_elapsed=24.3s
#     [train] batch 60/267 | running_acc=0.9972 | this_chunk=13.3s | total_elapsed=37.6s
#     [train] batch 80/267 | running_acc=0.9938 | this_chunk=10.9s | total_elapsed=48.6s
#     [train] batch 100/267 | running_acc=0.9900 | this_chunk=10.4s | total_elapsed=58.9s
#     [train] batch 120/267 | running_acc=0.9882 | this_chunk=10.5s | total_elapsed=69.5s
#     [train] batch 140/267 | running_acc=0.9875 | this_chunk=8.6s | total_elapsed=78.1s
#     [train] batch 160/267 | running_acc=0.9865 | this_chunk=9.9s | total_elapsed=87.9s
#     [train] batch 180/267 | running_acc=0.9861 | this_chunk=9.7s | total_elapsed=97.7s
#     [train] batch 200/267 | running_acc=0.9846 | this_chunk=8.4s | total_elapsed=106.1s
#     [train] batch 220/267 | running_acc=0.9837 | this_chunk=9.5s | total_elapsed=115.6s
#     [train] batch 240/267 | running_acc=0.9802 | this_chunk=10.4s | total_elapsed=125.9s
#     [train] batch 260/267 | running_acc=0.9792 | this_chunk=8.5s | total_elapsed=134.5s
#     [val] batch 20/34 | running_acc=0.9875 | this_chunk=5.1s | total_elapsed=5.1s
# [seed 42] Epoch 6/30 | train_loss=0.0572 train_acc=0.9781 | val_loss=0.0635 val_acc=0.9800
#   -> new best_val_acc=0.9800, saved best.pt
#     [train] batch 20/267 | running_acc=0.9708 | this_chunk=9.8s | total_elapsed=9.8s
#     [train] batch 40/267 | running_acc=0.9729 | this_chunk=13.5s | total_elapsed=23.3s
#     [train] batch 60/267 | running_acc=0.9708 | this_chunk=12.7s | total_elapsed=36.1s
#     [train] batch 80/267 | running_acc=0.9760 | this_chunk=12.8s | total_elapsed=48.9s
#     [train] batch 100/267 | running_acc=0.9808 | this_chunk=10.4s | total_elapsed=59.3s
#     [train] batch 120/267 | running_acc=0.9812 | this_chunk=10.5s | total_elapsed=69.9s
#     [train] batch 140/267 | running_acc=0.9833 | this_chunk=11.7s | total_elapsed=81.5s
#     [train] batch 160/267 | running_acc=0.9839 | this_chunk=10.5s | total_elapsed=92.0s
#     [train] batch 180/267 | running_acc=0.9843 | this_chunk=8.6s | total_elapsed=100.6s
#     [train] batch 200/267 | running_acc=0.9846 | this_chunk=10.0s | total_elapsed=110.6s
#     [train] batch 220/267 | running_acc=0.9848 | this_chunk=9.9s | total_elapsed=120.4s
#     [train] batch 240/267 | running_acc=0.9854 | this_chunk=8.9s | total_elapsed=129.3s
#     [train] batch 260/267 | running_acc=0.9862 | this_chunk=9.6s | total_elapsed=138.9s
#     [val] batch 20/34 | running_acc=0.9833 | this_chunk=6.8s | total_elapsed=6.8s
# [seed 42] Epoch 7/30 | train_loss=0.0438 train_acc=0.9859 | val_loss=0.0653 val_acc=0.9825
#   -> new best_val_acc=0.9825, saved best.pt
#     [train] batch 20/267 | running_acc=0.9875 | this_chunk=11.0s | total_elapsed=11.0s
#     [train] batch 40/267 | running_acc=0.9917 | this_chunk=13.3s | total_elapsed=24.3s
#     [train] batch 60/267 | running_acc=0.9861 | this_chunk=12.8s | total_elapsed=37.1s
#     [train] batch 80/267 | running_acc=0.9854 | this_chunk=11.6s | total_elapsed=48.7s
#     [train] batch 100/267 | running_acc=0.9833 | this_chunk=9.7s | total_elapsed=58.4s
#     [train] batch 120/267 | running_acc=0.9833 | this_chunk=10.9s | total_elapsed=69.3s
#     [train] batch 140/267 | running_acc=0.9857 | this_chunk=12.5s | total_elapsed=81.8s
#     [train] batch 160/267 | running_acc=0.9875 | this_chunk=9.0s | total_elapsed=90.9s
#     [train] batch 180/267 | running_acc=0.9889 | this_chunk=9.5s | total_elapsed=100.4s
#     [train] batch 200/267 | running_acc=0.9883 | this_chunk=10.4s | total_elapsed=110.8s
#     [train] batch 220/267 | running_acc=0.9883 | this_chunk=8.6s | total_elapsed=119.4s
#     [train] batch 240/267 | running_acc=0.9882 | this_chunk=9.9s | total_elapsed=129.3s
#     [train] batch 260/267 | running_acc=0.9885 | this_chunk=10.3s | total_elapsed=139.6s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=5.2s | total_elapsed=5.2s
# [seed 42] Epoch 8/30 | train_loss=0.0269 train_acc=0.9887 | val_loss=0.0694 val_acc=0.9775
#   -> no improvement for 1/6 epochs
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=9.5s | total_elapsed=9.5s
#     [train] batch 40/267 | running_acc=0.9979 | this_chunk=11.8s | total_elapsed=21.3s
#     [train] batch 60/267 | running_acc=0.9986 | this_chunk=14.2s | total_elapsed=35.5s
#     [train] batch 80/267 | running_acc=0.9990 | this_chunk=12.8s | total_elapsed=48.3s
#     [train] batch 100/267 | running_acc=0.9992 | this_chunk=11.2s | total_elapsed=59.5s
#     [train] batch 120/267 | running_acc=0.9979 | this_chunk=9.1s | total_elapsed=68.6s
#     [train] batch 140/267 | running_acc=0.9964 | this_chunk=9.3s | total_elapsed=77.9s
#     [train] batch 160/267 | running_acc=0.9953 | this_chunk=10.0s | total_elapsed=87.9s
#     [train] batch 180/267 | running_acc=0.9949 | this_chunk=8.6s | total_elapsed=96.5s
#     [train] batch 200/267 | running_acc=0.9954 | this_chunk=9.7s | total_elapsed=106.3s
#     [train] batch 220/267 | running_acc=0.9955 | this_chunk=10.3s | total_elapsed=116.6s
#     [train] batch 240/267 | running_acc=0.9948 | this_chunk=9.1s | total_elapsed=125.7s
#     [train] batch 260/267 | running_acc=0.9946 | this_chunk=9.7s | total_elapsed=135.4s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=7.1s | total_elapsed=7.1s
# [seed 42] Epoch 9/30 | train_loss=0.0165 train_acc=0.9947 | val_loss=0.0873 val_acc=0.9775
#   -> no improvement for 2/6 epochs
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=11.0s | total_elapsed=11.0s
#     [train] batch 40/267 | running_acc=0.9979 | this_chunk=12.9s | total_elapsed=23.9s
#     [train] batch 60/267 | running_acc=0.9986 | this_chunk=13.4s | total_elapsed=37.3s
#     [train] batch 80/267 | running_acc=0.9979 | this_chunk=11.4s | total_elapsed=48.7s
#     [train] batch 100/267 | running_acc=0.9967 | this_chunk=10.1s | total_elapsed=58.8s
#     [train] batch 120/267 | running_acc=0.9965 | this_chunk=10.7s | total_elapsed=69.4s
#     [train] batch 140/267 | running_acc=0.9964 | this_chunk=9.8s | total_elapsed=79.2s
#     [train] batch 160/267 | running_acc=0.9953 | this_chunk=8.5s | total_elapsed=87.7s
#     [train] batch 180/267 | running_acc=0.9949 | this_chunk=10.4s | total_elapsed=98.0s
#     [train] batch 200/267 | running_acc=0.9954 | this_chunk=9.5s | total_elapsed=107.6s
#     [train] batch 220/267 | running_acc=0.9958 | this_chunk=8.5s | total_elapsed=116.1s
#     [train] batch 240/267 | running_acc=0.9962 | this_chunk=10.0s | total_elapsed=126.1s
#     [train] batch 260/267 | running_acc=0.9965 | this_chunk=9.1s | total_elapsed=135.2s
#     [val] batch 20/34 | running_acc=0.9875 | this_chunk=5.3s | total_elapsed=5.3s
# [seed 42] Epoch 10/30 | train_loss=0.0123 train_acc=0.9966 | val_loss=0.0810 val_acc=0.9800
#   -> no improvement for 3/6 epochs
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=10.5s | total_elapsed=10.5s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=12.9s | total_elapsed=23.4s
#     [train] batch 60/267 | running_acc=0.9972 | this_chunk=13.4s | total_elapsed=36.8s
#     [train] batch 80/267 | running_acc=0.9958 | this_chunk=13.3s | total_elapsed=50.0s
#     [train] batch 100/267 | running_acc=0.9925 | this_chunk=9.6s | total_elapsed=59.6s
#     [train] batch 120/267 | running_acc=0.9938 | this_chunk=10.1s | total_elapsed=69.8s
#     [train] batch 140/267 | running_acc=0.9946 | this_chunk=10.2s | total_elapsed=80.0s
#     [train] batch 160/267 | running_acc=0.9953 | this_chunk=9.0s | total_elapsed=89.0s
#     [train] batch 180/267 | running_acc=0.9954 | this_chunk=9.7s | total_elapsed=98.6s
#     [train] batch 200/267 | running_acc=0.9946 | this_chunk=10.6s | total_elapsed=109.2s
#     [train] batch 220/267 | running_acc=0.9943 | this_chunk=9.8s | total_elapsed=119.1s
#     [train] batch 240/267 | running_acc=0.9944 | this_chunk=9.0s | total_elapsed=128.1s
#     [train] batch 260/267 | running_acc=0.9946 | this_chunk=10.1s | total_elapsed=138.1s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=5.9s | total_elapsed=5.9s
# [seed 42] Epoch 11/30 | train_loss=0.0123 train_acc=0.9944 | val_loss=0.0669 val_acc=0.9800
#   -> no improvement for 4/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=10.5s | total_elapsed=10.5s
#     [train] batch 40/267 | running_acc=1.0000 | this_chunk=10.7s | total_elapsed=21.2s
#     [train] batch 60/267 | running_acc=1.0000 | this_chunk=13.8s | total_elapsed=35.0s
#     [train] batch 80/267 | running_acc=0.9969 | this_chunk=12.5s | total_elapsed=47.5s
#     [train] batch 100/267 | running_acc=0.9958 | this_chunk=11.3s | total_elapsed=58.8s
#     [train] batch 120/267 | running_acc=0.9965 | this_chunk=10.6s | total_elapsed=69.4s
#     [train] batch 140/267 | running_acc=0.9952 | this_chunk=8.3s | total_elapsed=77.7s
#     [train] batch 160/267 | running_acc=0.9948 | this_chunk=10.1s | total_elapsed=87.8s
#     [train] batch 180/267 | running_acc=0.9944 | this_chunk=10.6s | total_elapsed=98.4s
#     [train] batch 200/267 | running_acc=0.9942 | this_chunk=8.3s | total_elapsed=106.7s
#     [train] batch 220/267 | running_acc=0.9947 | this_chunk=10.1s | total_elapsed=116.8s
#     [train] batch 240/267 | running_acc=0.9944 | this_chunk=10.0s | total_elapsed=126.7s
#     [train] batch 260/267 | running_acc=0.9942 | this_chunk=8.2s | total_elapsed=135.0s
#     [val] batch 20/34 | running_acc=0.9750 | this_chunk=6.5s | total_elapsed=6.5s
# [seed 42] Epoch 12/30 | train_loss=0.0154 train_acc=0.9944 | val_loss=0.1045 val_acc=0.9675
#   -> no improvement for 5/6 epochs
#     [train] batch 20/267 | running_acc=0.9875 | this_chunk=11.0s | total_elapsed=11.0s
#     [train] batch 40/267 | running_acc=0.9896 | this_chunk=12.2s | total_elapsed=23.2s
#     [train] batch 60/267 | running_acc=0.9931 | this_chunk=13.4s | total_elapsed=36.6s
#     [train] batch 80/267 | running_acc=0.9938 | this_chunk=12.4s | total_elapsed=49.0s
#     [train] batch 100/267 | running_acc=0.9950 | this_chunk=9.2s | total_elapsed=58.2s
#     [train] batch 120/267 | running_acc=0.9951 | this_chunk=10.9s | total_elapsed=69.1s
#     [train] batch 140/267 | running_acc=0.9952 | this_chunk=9.9s | total_elapsed=79.0s
#     [train] batch 160/267 | running_acc=0.9953 | this_chunk=8.3s | total_elapsed=87.3s
#     [train] batch 180/267 | running_acc=0.9958 | this_chunk=9.9s | total_elapsed=97.2s
#     [train] batch 200/267 | running_acc=0.9962 | this_chunk=9.9s | total_elapsed=107.1s
#     [train] batch 220/267 | running_acc=0.9958 | this_chunk=8.2s | total_elapsed=115.3s
#     [train] batch 240/267 | running_acc=0.9958 | this_chunk=9.7s | total_elapsed=125.0s
#     [train] batch 260/267 | running_acc=0.9962 | this_chunk=10.3s | total_elapsed=135.3s
#     [val] batch 20/34 | running_acc=0.9833 | this_chunk=5.0s | total_elapsed=5.0s
# [seed 42] Epoch 13/30 | train_loss=0.0105 train_acc=0.9959 | val_loss=0.0858 val_acc=0.9775
#   -> no improvement for 6/6 epochs
# Stopping early for seed 42: no improvement for 6 epochs.
# Finalized /content/drive/MyDrive/gastronet_experiments/hybrid_concat_v2/seed_42: removed latest.pt (best.pt + results.json verified present).
# Seed 42 done. test_acc=0.9775. latest.pt cleaned up.
#
#
# ============================================================
# Starting SEED=123
# ============================================================
# [/content/drive/MyDrive/gastronet_experiments/hybrid_concat_v2/seed_123] No latest.pt found -- starting fresh at epoch 0.
#     [train] batch 20/267 | running_acc=0.6125 | this_chunk=11.2s | total_elapsed=11.2s
#     [train] batch 40/267 | running_acc=0.7583 | this_chunk=10.3s | total_elapsed=21.6s
#     [train] batch 60/267 | running_acc=0.8194 | this_chunk=9.4s | total_elapsed=30.9s
#     [train] batch 80/267 | running_acc=0.8354 | this_chunk=8.6s | total_elapsed=39.5s
#     [train] batch 100/267 | running_acc=0.8592 | this_chunk=9.7s | total_elapsed=49.2s
#     [train] batch 120/267 | running_acc=0.8688 | this_chunk=9.2s | total_elapsed=58.4s
#     [train] batch 140/267 | running_acc=0.8720 | this_chunk=8.7s | total_elapsed=67.2s
#     [train] batch 160/267 | running_acc=0.8792 | this_chunk=10.2s | total_elapsed=77.4s
#     [train] batch 180/267 | running_acc=0.8838 | this_chunk=8.7s | total_elapsed=86.1s
#     [train] batch 200/267 | running_acc=0.8875 | this_chunk=9.3s | total_elapsed=95.4s
#     [train] batch 220/267 | running_acc=0.8867 | this_chunk=9.7s | total_elapsed=105.1s
#     [train] batch 240/267 | running_acc=0.8931 | this_chunk=9.2s | total_elapsed=114.3s
#     [train] batch 260/267 | running_acc=0.8981 | this_chunk=8.8s | total_elapsed=123.1s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=6.5s | total_elapsed=6.5s
# [seed 123] Epoch 1/30 | train_loss=0.2773 train_acc=0.8996 | val_loss=0.1797 val_acc=0.9400
#   -> new best_val_acc=0.9400, saved best.pt
#     [train] batch 20/267 | running_acc=0.9417 | this_chunk=11.9s | total_elapsed=11.9s
#     [train] batch 40/267 | running_acc=0.9479 | this_chunk=10.6s | total_elapsed=22.4s
#     [train] batch 60/267 | running_acc=0.9431 | this_chunk=8.9s | total_elapsed=31.3s
#     [train] batch 80/267 | running_acc=0.9521 | this_chunk=9.3s | total_elapsed=40.6s
#     [train] batch 100/267 | running_acc=0.9525 | this_chunk=9.5s | total_elapsed=50.1s
#     [train] batch 120/267 | running_acc=0.9583 | this_chunk=8.7s | total_elapsed=58.8s
#     [train] batch 140/267 | running_acc=0.9601 | this_chunk=9.5s | total_elapsed=68.3s
#     [train] batch 160/267 | running_acc=0.9625 | this_chunk=9.8s | total_elapsed=78.2s
#     [train] batch 180/267 | running_acc=0.9630 | this_chunk=8.4s | total_elapsed=86.6s
#     [train] batch 200/267 | running_acc=0.9637 | this_chunk=9.8s | total_elapsed=96.4s
#     [train] batch 220/267 | running_acc=0.9621 | this_chunk=9.8s | total_elapsed=106.2s
#     [train] batch 240/267 | running_acc=0.9611 | this_chunk=8.2s | total_elapsed=114.4s
#     [train] batch 260/267 | running_acc=0.9619 | this_chunk=10.1s | total_elapsed=124.4s
#     [val] batch 20/34 | running_acc=0.9667 | this_chunk=6.6s | total_elapsed=6.6s
# [seed 123] Epoch 2/30 | train_loss=0.1154 train_acc=0.9612 | val_loss=0.1225 val_acc=0.9650
#   -> new best_val_acc=0.9650, saved best.pt
#     [train] batch 20/267 | running_acc=0.9750 | this_chunk=10.8s | total_elapsed=10.8s
#     [train] batch 40/267 | running_acc=0.9771 | this_chunk=13.1s | total_elapsed=23.9s
#     [train] batch 60/267 | running_acc=0.9819 | this_chunk=12.7s | total_elapsed=36.6s
#     [train] batch 80/267 | running_acc=0.9823 | this_chunk=11.5s | total_elapsed=48.1s
#     [train] batch 100/267 | running_acc=0.9808 | this_chunk=9.7s | total_elapsed=57.8s
#     [train] batch 120/267 | running_acc=0.9812 | this_chunk=11.2s | total_elapsed=69.0s
#     [train] batch 140/267 | running_acc=0.9815 | this_chunk=11.8s | total_elapsed=80.9s
#     [train] batch 160/267 | running_acc=0.9828 | this_chunk=8.3s | total_elapsed=89.2s
#     [train] batch 180/267 | running_acc=0.9810 | this_chunk=9.9s | total_elapsed=99.0s
#     [train] batch 200/267 | running_acc=0.9779 | this_chunk=10.0s | total_elapsed=109.0s
#     [train] batch 220/267 | running_acc=0.9761 | this_chunk=8.5s | total_elapsed=117.5s
#     [train] batch 240/267 | running_acc=0.9750 | this_chunk=9.4s | total_elapsed=126.9s
#     [train] batch 260/267 | running_acc=0.9750 | this_chunk=10.0s | total_elapsed=137.0s
#     [val] batch 20/34 | running_acc=0.9750 | this_chunk=4.9s | total_elapsed=4.9s
# [seed 123] Epoch 3/30 | train_loss=0.0783 train_acc=0.9753 | val_loss=0.1196 val_acc=0.9525
#   -> no improvement for 1/6 epochs
#     [train] batch 20/267 | running_acc=0.9833 | this_chunk=10.6s | total_elapsed=10.6s
#     [train] batch 40/267 | running_acc=0.9875 | this_chunk=11.1s | total_elapsed=21.7s
#     [train] batch 60/267 | running_acc=0.9792 | this_chunk=13.2s | total_elapsed=35.0s
#     [train] batch 80/267 | running_acc=0.9802 | this_chunk=12.4s | total_elapsed=47.4s
#     [train] batch 100/267 | running_acc=0.9792 | this_chunk=10.5s | total_elapsed=57.8s
#     [train] batch 120/267 | running_acc=0.9826 | this_chunk=9.9s | total_elapsed=67.7s
#     [train] batch 140/267 | running_acc=0.9845 | this_chunk=8.8s | total_elapsed=76.5s
#     [train] batch 160/267 | running_acc=0.9854 | this_chunk=9.9s | total_elapsed=86.4s
#     [train] batch 180/267 | running_acc=0.9866 | this_chunk=9.2s | total_elapsed=95.6s
#     [train] batch 200/267 | running_acc=0.9842 | this_chunk=9.2s | total_elapsed=104.8s
#     [train] batch 220/267 | running_acc=0.9826 | this_chunk=10.1s | total_elapsed=114.9s
#     [train] batch 240/267 | running_acc=0.9830 | this_chunk=8.8s | total_elapsed=123.6s
#     [train] batch 260/267 | running_acc=0.9824 | this_chunk=9.3s | total_elapsed=133.0s
#     [val] batch 20/34 | running_acc=0.9875 | this_chunk=6.7s | total_elapsed=6.7s
# [seed 123] Epoch 4/30 | train_loss=0.0505 train_acc=0.9825 | val_loss=0.0561 val_acc=0.9850
#   -> new best_val_acc=0.9850, saved best.pt
#     [train] batch 20/267 | running_acc=0.9792 | this_chunk=11.4s | total_elapsed=11.4s
#     [train] batch 40/267 | running_acc=0.9812 | this_chunk=12.9s | total_elapsed=24.2s
#     [train] batch 60/267 | running_acc=0.9861 | this_chunk=13.2s | total_elapsed=37.5s
#     [train] batch 80/267 | running_acc=0.9802 | this_chunk=12.3s | total_elapsed=49.7s
#     [train] batch 100/267 | running_acc=0.9792 | this_chunk=9.3s | total_elapsed=59.0s
#     [train] batch 120/267 | running_acc=0.9785 | this_chunk=11.2s | total_elapsed=70.2s
#     [train] batch 140/267 | running_acc=0.9810 | this_chunk=11.8s | total_elapsed=82.0s
#     [train] batch 160/267 | running_acc=0.9823 | this_chunk=9.7s | total_elapsed=91.7s
#     [train] batch 180/267 | running_acc=0.9833 | this_chunk=8.3s | total_elapsed=100.0s
#     [train] batch 200/267 | running_acc=0.9842 | this_chunk=9.5s | total_elapsed=109.5s
#     [train] batch 220/267 | running_acc=0.9841 | this_chunk=9.2s | total_elapsed=118.7s
#     [train] batch 240/267 | running_acc=0.9844 | this_chunk=9.1s | total_elapsed=127.7s
#     [train] batch 260/267 | running_acc=0.9837 | this_chunk=9.4s | total_elapsed=137.1s
#     [val] batch 20/34 | running_acc=0.9708 | this_chunk=5.8s | total_elapsed=5.8s
# [seed 123] Epoch 5/30 | train_loss=0.0438 train_acc=0.9837 | val_loss=0.0951 val_acc=0.9625
#   -> no improvement for 1/6 epochs
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=11.1s | total_elapsed=11.1s
#     [train] batch 40/267 | running_acc=0.9917 | this_chunk=11.8s | total_elapsed=22.9s
#     [train] batch 60/267 | running_acc=0.9875 | this_chunk=12.0s | total_elapsed=34.9s
#     [train] batch 80/267 | running_acc=0.9833 | this_chunk=12.1s | total_elapsed=47.0s
#     [train] batch 100/267 | running_acc=0.9867 | this_chunk=10.3s | total_elapsed=57.3s
#     [train] batch 120/267 | running_acc=0.9840 | this_chunk=10.4s | total_elapsed=67.7s
#     [train] batch 140/267 | running_acc=0.9851 | this_chunk=8.2s | total_elapsed=75.9s
#     [train] batch 160/267 | running_acc=0.9839 | this_chunk=9.8s | total_elapsed=85.7s
#     [train] batch 180/267 | running_acc=0.9843 | this_chunk=10.0s | total_elapsed=95.7s
#     [train] batch 200/267 | running_acc=0.9846 | this_chunk=8.1s | total_elapsed=103.8s
#     [train] batch 220/267 | running_acc=0.9845 | this_chunk=10.0s | total_elapsed=113.8s
#     [train] batch 240/267 | running_acc=0.9844 | this_chunk=9.8s | total_elapsed=123.6s
#     [train] batch 260/267 | running_acc=0.9843 | this_chunk=8.1s | total_elapsed=131.7s
#     [val] batch 20/34 | running_acc=0.9875 | this_chunk=5.6s | total_elapsed=5.6s
# [seed 123] Epoch 6/30 | train_loss=0.0473 train_acc=0.9844 | val_loss=0.0699 val_acc=0.9750
#   -> no improvement for 2/6 epochs
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=10.7s | total_elapsed=10.7s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=12.4s | total_elapsed=23.1s
#     [train] batch 60/267 | running_acc=0.9958 | this_chunk=13.3s | total_elapsed=36.4s
#     [train] batch 80/267 | running_acc=0.9938 | this_chunk=12.0s | total_elapsed=48.4s
#     [train] batch 100/267 | running_acc=0.9925 | this_chunk=9.2s | total_elapsed=57.6s
#     [train] batch 120/267 | running_acc=0.9903 | this_chunk=10.1s | total_elapsed=67.7s
#     [train] batch 140/267 | running_acc=0.9881 | this_chunk=10.1s | total_elapsed=77.8s
#     [train] batch 160/267 | running_acc=0.9880 | this_chunk=8.0s | total_elapsed=85.8s
#     [train] batch 180/267 | running_acc=0.9884 | this_chunk=10.1s | total_elapsed=95.9s
#     [train] batch 200/267 | running_acc=0.9871 | this_chunk=9.5s | total_elapsed=105.4s
#     [train] batch 220/267 | running_acc=0.9856 | this_chunk=8.5s | total_elapsed=113.9s
#     [train] batch 240/267 | running_acc=0.9851 | this_chunk=9.8s | total_elapsed=123.7s
#     [train] batch 260/267 | running_acc=0.9849 | this_chunk=9.8s | total_elapsed=133.5s
#     [val] batch 20/34 | running_acc=0.9458 | this_chunk=5.1s | total_elapsed=5.1s
# [seed 123] Epoch 7/30 | train_loss=0.0413 train_acc=0.9850 | val_loss=0.1574 val_acc=0.9450
#   -> no improvement for 3/6 epochs
#     [train] batch 20/267 | running_acc=0.9917 | this_chunk=9.1s | total_elapsed=9.1s
#     [train] batch 40/267 | running_acc=0.9917 | this_chunk=12.4s | total_elapsed=21.5s
#     [train] batch 60/267 | running_acc=0.9944 | this_chunk=13.7s | total_elapsed=35.2s
#     [train] batch 80/267 | running_acc=0.9958 | this_chunk=11.9s | total_elapsed=47.1s
#     [train] batch 100/267 | running_acc=0.9958 | this_chunk=10.6s | total_elapsed=57.7s
#     [train] batch 120/267 | running_acc=0.9951 | this_chunk=9.0s | total_elapsed=66.7s
#     [train] batch 140/267 | running_acc=0.9940 | this_chunk=9.8s | total_elapsed=76.5s
#     [train] batch 160/267 | running_acc=0.9927 | this_chunk=9.8s | total_elapsed=86.3s
#     [train] batch 180/267 | running_acc=0.9926 | this_chunk=8.2s | total_elapsed=94.4s
#     [train] batch 200/267 | running_acc=0.9912 | this_chunk=10.0s | total_elapsed=104.5s
#     [train] batch 220/267 | running_acc=0.9909 | this_chunk=9.6s | total_elapsed=114.1s
#     [train] batch 240/267 | running_acc=0.9913 | this_chunk=8.4s | total_elapsed=122.5s
#     [train] batch 260/267 | running_acc=0.9917 | this_chunk=9.5s | total_elapsed=132.0s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=6.4s | total_elapsed=6.4s
# [seed 123] Epoch 8/30 | train_loss=0.0275 train_acc=0.9916 | val_loss=0.0661 val_acc=0.9800
#   -> no improvement for 4/6 epochs
#     [train] batch 20/267 | running_acc=0.9917 | this_chunk=11.2s | total_elapsed=11.2s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=12.4s | total_elapsed=23.6s
#     [train] batch 60/267 | running_acc=0.9958 | this_chunk=12.2s | total_elapsed=35.8s
#     [train] batch 80/267 | running_acc=0.9969 | this_chunk=11.7s | total_elapsed=47.6s
#     [train] batch 100/267 | running_acc=0.9975 | this_chunk=10.5s | total_elapsed=58.1s
#     [train] batch 120/267 | running_acc=0.9972 | this_chunk=10.2s | total_elapsed=68.3s
#     [train] batch 140/267 | running_acc=0.9976 | this_chunk=8.1s | total_elapsed=76.4s
#     [train] batch 160/267 | running_acc=0.9969 | this_chunk=10.0s | total_elapsed=86.3s
#     [train] batch 180/267 | running_acc=0.9972 | this_chunk=10.0s | total_elapsed=96.3s
#     [train] batch 200/267 | running_acc=0.9971 | this_chunk=8.2s | total_elapsed=104.5s
#     [train] batch 220/267 | running_acc=0.9970 | this_chunk=9.7s | total_elapsed=114.2s
#     [train] batch 240/267 | running_acc=0.9965 | this_chunk=9.9s | total_elapsed=124.1s
#     [train] batch 260/267 | running_acc=0.9968 | this_chunk=8.3s | total_elapsed=132.4s
#     [val] batch 20/34 | running_acc=0.9792 | this_chunk=5.5s | total_elapsed=5.5s
# [seed 123] Epoch 9/30 | train_loss=0.0087 train_acc=0.9966 | val_loss=0.1189 val_acc=0.9725
#   -> no improvement for 5/6 epochs
#     [train] batch 20/267 | running_acc=0.9875 | this_chunk=10.6s | total_elapsed=10.6s
#     [train] batch 40/267 | running_acc=0.9854 | this_chunk=12.5s | total_elapsed=23.0s
#     [train] batch 60/267 | running_acc=0.9847 | this_chunk=12.8s | total_elapsed=35.8s
#     [train] batch 80/267 | running_acc=0.9854 | this_chunk=12.6s | total_elapsed=48.4s
#     [train] batch 100/267 | running_acc=0.9867 | this_chunk=9.0s | total_elapsed=57.4s
#     [train] batch 120/267 | running_acc=0.9882 | this_chunk=10.2s | total_elapsed=67.6s
#     [train] batch 140/267 | running_acc=0.9899 | this_chunk=9.8s | total_elapsed=77.3s
#     [train] batch 160/267 | running_acc=0.9911 | this_chunk=8.0s | total_elapsed=85.3s
#     [train] batch 180/267 | running_acc=0.9917 | this_chunk=10.0s | total_elapsed=95.3s
#     [train] batch 200/267 | running_acc=0.9912 | this_chunk=10.0s | total_elapsed=105.3s
#     [train] batch 220/267 | running_acc=0.9913 | this_chunk=8.3s | total_elapsed=113.6s
#     [train] batch 240/267 | running_acc=0.9917 | this_chunk=10.0s | total_elapsed=123.5s
#     [train] batch 260/267 | running_acc=0.9913 | this_chunk=9.7s | total_elapsed=133.2s
#     [val] batch 20/34 | running_acc=0.9958 | this_chunk=5.0s | total_elapsed=5.0s
# [seed 123] Epoch 10/30 | train_loss=0.0239 train_acc=0.9916 | val_loss=0.0801 val_acc=0.9800
#   -> no improvement for 6/6 epochs
# Stopping early for seed 123: no improvement for 6 epochs.
# Finalized /content/drive/MyDrive/gastronet_experiments/hybrid_concat_v2/seed_123: removed latest.pt (best.pt + results.json verified present).
# Seed 123 done. test_acc=0.9750. latest.pt cleaned up.
#
#
# ============================================================
# Starting SEED=7
# ============================================================
# [/content/drive/MyDrive/gastronet_experiments/hybrid_concat_v2/seed_7] No latest.pt found -- starting fresh at epoch 0.
#     [train] batch 20/267 | running_acc=0.5667 | this_chunk=12.2s | total_elapsed=12.2s
#     [train] batch 40/267 | running_acc=0.7292 | this_chunk=10.5s | total_elapsed=22.7s
#     [train] batch 60/267 | running_acc=0.7764 | this_chunk=8.5s | total_elapsed=31.2s
#     [train] batch 80/267 | running_acc=0.8135 | this_chunk=9.5s | total_elapsed=40.7s
#     [train] batch 100/267 | running_acc=0.8367 | this_chunk=9.7s | total_elapsed=50.3s
#     [train] batch 120/267 | running_acc=0.8542 | this_chunk=8.5s | total_elapsed=58.8s
#     [train] batch 140/267 | running_acc=0.8577 | this_chunk=9.9s | total_elapsed=68.7s
#     [train] batch 160/267 | running_acc=0.8661 | this_chunk=9.7s | total_elapsed=78.5s
#     [train] batch 180/267 | running_acc=0.8764 | this_chunk=8.4s | total_elapsed=86.9s
#     [train] batch 200/267 | running_acc=0.8854 | this_chunk=9.9s | total_elapsed=96.7s
#     [train] batch 220/267 | running_acc=0.8928 | this_chunk=9.9s | total_elapsed=106.7s
#     [train] batch 240/267 | running_acc=0.8976 | this_chunk=9.0s | total_elapsed=115.6s
#     [train] batch 260/267 | running_acc=0.9006 | this_chunk=9.7s | total_elapsed=125.3s
#     [val] batch 20/34 | running_acc=0.9708 | this_chunk=6.7s | total_elapsed=6.7s
# [seed 7] Epoch 1/30 | train_loss=0.2692 train_acc=0.9028 | val_loss=0.1471 val_acc=0.9375
#   -> new best_val_acc=0.9375, saved best.pt
#     [train] batch 20/267 | running_acc=0.9542 | this_chunk=12.0s | total_elapsed=12.0s
#     [train] batch 40/267 | running_acc=0.9667 | this_chunk=10.6s | total_elapsed=22.6s
#     [train] batch 60/267 | running_acc=0.9556 | this_chunk=8.5s | total_elapsed=31.2s
#     [train] batch 80/267 | running_acc=0.9531 | this_chunk=9.7s | total_elapsed=40.9s
#     [train] batch 100/267 | running_acc=0.9575 | this_chunk=10.0s | total_elapsed=50.8s
#     [train] batch 120/267 | running_acc=0.9576 | this_chunk=8.5s | total_elapsed=59.3s
#     [train] batch 140/267 | running_acc=0.9577 | this_chunk=9.5s | total_elapsed=68.8s
#     [train] batch 160/267 | running_acc=0.9578 | this_chunk=10.0s | total_elapsed=78.8s
#     [train] batch 180/267 | running_acc=0.9593 | this_chunk=8.4s | total_elapsed=87.2s
#     [train] batch 200/267 | running_acc=0.9583 | this_chunk=9.4s | total_elapsed=96.6s
#     [train] batch 220/267 | running_acc=0.9576 | this_chunk=9.9s | total_elapsed=106.5s
#     [train] batch 240/267 | running_acc=0.9569 | this_chunk=8.7s | total_elapsed=115.2s
#     [train] batch 260/267 | running_acc=0.9583 | this_chunk=9.3s | total_elapsed=124.5s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=6.6s | total_elapsed=6.6s
# [seed 7] Epoch 2/30 | train_loss=0.1234 train_acc=0.9584 | val_loss=0.1208 val_acc=0.9550
#   -> new best_val_acc=0.9550, saved best.pt
#     [train] batch 20/267 | running_acc=0.9667 | this_chunk=10.5s | total_elapsed=10.5s
#     [train] batch 40/267 | running_acc=0.9792 | this_chunk=12.4s | total_elapsed=22.9s
#     [train] batch 60/267 | running_acc=0.9792 | this_chunk=12.6s | total_elapsed=35.5s
#     [train] batch 80/267 | running_acc=0.9792 | this_chunk=11.7s | total_elapsed=47.3s
#     [train] batch 100/267 | running_acc=0.9800 | this_chunk=10.3s | total_elapsed=57.5s
#     [train] batch 120/267 | running_acc=0.9806 | this_chunk=11.3s | total_elapsed=68.8s
#     [train] batch 140/267 | running_acc=0.9792 | this_chunk=12.0s | total_elapsed=80.8s
#     [train] batch 160/267 | running_acc=0.9792 | this_chunk=8.6s | total_elapsed=89.4s
#     [train] batch 180/267 | running_acc=0.9801 | this_chunk=9.3s | total_elapsed=98.7s
#     [train] batch 200/267 | running_acc=0.9800 | this_chunk=9.7s | total_elapsed=108.4s
#     [train] batch 220/267 | running_acc=0.9784 | this_chunk=8.6s | total_elapsed=117.0s
#     [train] batch 240/267 | running_acc=0.9792 | this_chunk=9.7s | total_elapsed=126.7s
#     [train] batch 260/267 | running_acc=0.9792 | this_chunk=9.9s | total_elapsed=136.5s
#     [val] batch 20/34 | running_acc=0.9833 | this_chunk=5.0s | total_elapsed=5.0s
# [seed 7] Epoch 3/30 | train_loss=0.0615 train_acc=0.9794 | val_loss=0.0745 val_acc=0.9775
#   -> new best_val_acc=0.9775, saved best.pt
#     [train] batch 20/267 | running_acc=0.9750 | this_chunk=10.2s | total_elapsed=10.2s
#     [train] batch 40/267 | running_acc=0.9833 | this_chunk=12.2s | total_elapsed=22.3s
#     [train] batch 60/267 | running_acc=0.9792 | this_chunk=13.5s | total_elapsed=35.8s
#     [train] batch 80/267 | running_acc=0.9802 | this_chunk=11.8s | total_elapsed=47.6s
#     [train] batch 100/267 | running_acc=0.9792 | this_chunk=10.4s | total_elapsed=58.0s
#     [train] batch 120/267 | running_acc=0.9778 | this_chunk=10.9s | total_elapsed=68.9s
#     [train] batch 140/267 | running_acc=0.9804 | this_chunk=11.5s | total_elapsed=80.4s
#     [train] batch 160/267 | running_acc=0.9828 | this_chunk=9.3s | total_elapsed=89.7s
#     [train] batch 180/267 | running_acc=0.9843 | this_chunk=9.6s | total_elapsed=99.3s
#     [train] batch 200/267 | running_acc=0.9846 | this_chunk=8.5s | total_elapsed=107.8s
#     [train] batch 220/267 | running_acc=0.9856 | this_chunk=9.5s | total_elapsed=117.3s
#     [train] batch 240/267 | running_acc=0.9851 | this_chunk=9.7s | total_elapsed=127.0s
#     [train] batch 260/267 | running_acc=0.9846 | this_chunk=8.6s | total_elapsed=135.6s
#     [val] batch 20/34 | running_acc=0.9792 | this_chunk=4.9s | total_elapsed=4.9s
# [seed 7] Epoch 4/30 | train_loss=0.0467 train_acc=0.9844 | val_loss=0.0651 val_acc=0.9750
#   -> no improvement for 1/6 epochs
#     [train] batch 20/267 | running_acc=0.9625 | this_chunk=10.3s | total_elapsed=10.3s
#     [train] batch 40/267 | running_acc=0.9729 | this_chunk=12.3s | total_elapsed=22.6s
#     [train] batch 60/267 | running_acc=0.9806 | this_chunk=12.7s | total_elapsed=35.3s
#     [train] batch 80/267 | running_acc=0.9844 | this_chunk=12.5s | total_elapsed=47.8s
#     [train] batch 100/267 | running_acc=0.9817 | this_chunk=9.5s | total_elapsed=57.3s
#     [train] batch 120/267 | running_acc=0.9806 | this_chunk=9.8s | total_elapsed=67.1s
#     [train] batch 140/267 | running_acc=0.9798 | this_chunk=10.0s | total_elapsed=77.1s
#     [train] batch 160/267 | running_acc=0.9823 | this_chunk=8.4s | total_elapsed=85.5s
#     [train] batch 180/267 | running_acc=0.9824 | this_chunk=9.7s | total_elapsed=95.2s
#     [train] batch 200/267 | running_acc=0.9838 | this_chunk=9.8s | total_elapsed=105.0s
#     [train] batch 220/267 | running_acc=0.9841 | this_chunk=9.0s | total_elapsed=114.0s
#     [train] batch 240/267 | running_acc=0.9833 | this_chunk=9.5s | total_elapsed=123.5s
#     [train] batch 260/267 | running_acc=0.9833 | this_chunk=9.9s | total_elapsed=133.4s
#     [val] batch 20/34 | running_acc=0.9833 | this_chunk=5.0s | total_elapsed=5.0s
# [seed 7] Epoch 5/30 | train_loss=0.0468 train_acc=0.9834 | val_loss=0.0676 val_acc=0.9775
#   -> no improvement for 2/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=10.0s | total_elapsed=10.0s
#     [train] batch 40/267 | running_acc=0.9979 | this_chunk=11.9s | total_elapsed=22.0s
#     [train] batch 60/267 | running_acc=0.9903 | this_chunk=12.4s | total_elapsed=34.4s
#     [train] batch 80/267 | running_acc=0.9896 | this_chunk=12.3s | total_elapsed=46.7s
#     [train] batch 100/267 | running_acc=0.9900 | this_chunk=10.5s | total_elapsed=57.2s
#     [train] batch 120/267 | running_acc=0.9889 | this_chunk=9.3s | total_elapsed=66.5s
#     [train] batch 140/267 | running_acc=0.9893 | this_chunk=9.1s | total_elapsed=75.6s
#     [train] batch 160/267 | running_acc=0.9891 | this_chunk=9.9s | total_elapsed=85.5s
#     [train] batch 180/267 | running_acc=0.9898 | this_chunk=9.3s | total_elapsed=94.8s
#     [train] batch 200/267 | running_acc=0.9904 | this_chunk=8.9s | total_elapsed=103.7s
#     [train] batch 220/267 | running_acc=0.9902 | this_chunk=10.0s | total_elapsed=113.7s
#     [train] batch 240/267 | running_acc=0.9906 | this_chunk=8.5s | total_elapsed=122.1s
#     [train] batch 260/267 | running_acc=0.9907 | this_chunk=9.4s | total_elapsed=131.6s
#     [val] batch 20/34 | running_acc=0.9958 | this_chunk=6.7s | total_elapsed=6.7s
# [seed 7] Epoch 6/30 | train_loss=0.0241 train_acc=0.9906 | val_loss=0.0904 val_acc=0.9800
#   -> new best_val_acc=0.9800, saved best.pt
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=10.8s | total_elapsed=10.8s
#     [train] batch 40/267 | running_acc=0.9917 | this_chunk=12.7s | total_elapsed=23.5s
#     [train] batch 60/267 | running_acc=0.9889 | this_chunk=12.7s | total_elapsed=36.2s
#     [train] batch 80/267 | running_acc=0.9875 | this_chunk=11.2s | total_elapsed=47.3s
#     [train] batch 100/267 | running_acc=0.9850 | this_chunk=10.6s | total_elapsed=58.0s
#     [train] batch 120/267 | running_acc=0.9833 | this_chunk=12.4s | total_elapsed=70.3s
#     [train] batch 140/267 | running_acc=0.9827 | this_chunk=10.8s | total_elapsed=81.1s
#     [train] batch 160/267 | running_acc=0.9823 | this_chunk=8.9s | total_elapsed=90.0s
#     [train] batch 180/267 | running_acc=0.9838 | this_chunk=9.4s | total_elapsed=99.4s
#     [train] batch 200/267 | running_acc=0.9838 | this_chunk=9.9s | total_elapsed=109.3s
#     [train] batch 220/267 | running_acc=0.9837 | this_chunk=8.1s | total_elapsed=117.4s
#     [train] batch 240/267 | running_acc=0.9844 | this_chunk=10.1s | total_elapsed=127.5s
#     [train] batch 260/267 | running_acc=0.9849 | this_chunk=9.6s | total_elapsed=137.1s
#     [val] batch 20/34 | running_acc=0.9708 | this_chunk=4.9s | total_elapsed=4.9s
# [seed 7] Epoch 7/30 | train_loss=0.0396 train_acc=0.9853 | val_loss=0.0830 val_acc=0.9750
#   -> no improvement for 1/6 epochs
#     [train] batch 20/267 | running_acc=0.9958 | this_chunk=9.5s | total_elapsed=9.5s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=12.0s | total_elapsed=21.4s
#     [train] batch 60/267 | running_acc=0.9958 | this_chunk=12.4s | total_elapsed=33.8s
#     [train] batch 80/267 | running_acc=0.9938 | this_chunk=12.8s | total_elapsed=46.7s
#     [train] batch 100/267 | running_acc=0.9933 | this_chunk=10.7s | total_elapsed=57.4s
#     [train] batch 120/267 | running_acc=0.9931 | this_chunk=9.0s | total_elapsed=66.4s
#     [train] batch 140/267 | running_acc=0.9929 | this_chunk=9.3s | total_elapsed=75.7s
#     [train] batch 160/267 | running_acc=0.9927 | this_chunk=10.0s | total_elapsed=85.7s
#     [train] batch 180/267 | running_acc=0.9931 | this_chunk=8.5s | total_elapsed=94.1s
#     [train] batch 200/267 | running_acc=0.9929 | this_chunk=9.2s | total_elapsed=103.3s
#     [train] batch 220/267 | running_acc=0.9909 | this_chunk=10.1s | total_elapsed=113.4s
#     [train] batch 240/267 | running_acc=0.9903 | this_chunk=8.5s | total_elapsed=121.9s
#     [train] batch 260/267 | running_acc=0.9907 | this_chunk=9.9s | total_elapsed=131.7s
#     [val] batch 20/34 | running_acc=0.9750 | this_chunk=6.6s | total_elapsed=6.6s
# [seed 7] Epoch 8/30 | train_loss=0.0253 train_acc=0.9906 | val_loss=0.0964 val_acc=0.9700
#   -> no improvement for 2/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=11.5s | total_elapsed=11.5s
#     [train] batch 40/267 | running_acc=0.9979 | this_chunk=12.8s | total_elapsed=24.3s
#     [train] batch 60/267 | running_acc=0.9958 | this_chunk=12.7s | total_elapsed=37.0s
#     [train] batch 80/267 | running_acc=0.9969 | this_chunk=10.2s | total_elapsed=47.2s
#     [train] batch 100/267 | running_acc=0.9975 | this_chunk=10.5s | total_elapsed=57.8s
#     [train] batch 120/267 | running_acc=0.9951 | this_chunk=9.8s | total_elapsed=67.6s
#     [train] batch 140/267 | running_acc=0.9958 | this_chunk=8.6s | total_elapsed=76.2s
#     [train] batch 160/267 | running_acc=0.9958 | this_chunk=9.5s | total_elapsed=85.7s
#     [train] batch 180/267 | running_acc=0.9963 | this_chunk=9.6s | total_elapsed=95.3s
#     [train] batch 200/267 | running_acc=0.9962 | this_chunk=8.4s | total_elapsed=103.7s
#     [train] batch 220/267 | running_acc=0.9962 | this_chunk=9.9s | total_elapsed=113.6s
#     [train] batch 240/267 | running_acc=0.9965 | this_chunk=9.7s | total_elapsed=123.3s
#     [train] batch 260/267 | running_acc=0.9965 | this_chunk=8.0s | total_elapsed=131.3s
#     [val] batch 20/34 | running_acc=0.9958 | this_chunk=4.9s | total_elapsed=4.9s
# [seed 7] Epoch 9/30 | train_loss=0.0090 train_acc=0.9966 | val_loss=0.1000 val_acc=0.9800
#   -> no improvement for 3/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=10.8s | total_elapsed=10.8s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=12.6s | total_elapsed=23.5s
#     [train] batch 60/267 | running_acc=0.9972 | this_chunk=12.5s | total_elapsed=35.9s
#     [train] batch 80/267 | running_acc=0.9979 | this_chunk=12.6s | total_elapsed=48.5s
#     [train] batch 100/267 | running_acc=0.9983 | this_chunk=9.1s | total_elapsed=57.6s
#     [train] batch 120/267 | running_acc=0.9944 | this_chunk=10.2s | total_elapsed=67.8s
#     [train] batch 140/267 | running_acc=0.9929 | this_chunk=10.1s | total_elapsed=77.9s
#     [train] batch 160/267 | running_acc=0.9922 | this_chunk=8.2s | total_elapsed=86.1s
#     [train] batch 180/267 | running_acc=0.9926 | this_chunk=10.0s | total_elapsed=96.2s
#     [train] batch 200/267 | running_acc=0.9933 | this_chunk=9.4s | total_elapsed=105.6s
#     [train] batch 220/267 | running_acc=0.9939 | this_chunk=8.7s | total_elapsed=114.3s
#     [train] batch 240/267 | running_acc=0.9941 | this_chunk=9.8s | total_elapsed=124.1s
#     [train] batch 260/267 | running_acc=0.9936 | this_chunk=9.7s | total_elapsed=133.8s
#     [val] batch 20/34 | running_acc=0.9750 | this_chunk=4.9s | total_elapsed=4.9s
# [seed 7] Epoch 10/30 | train_loss=0.0212 train_acc=0.9937 | val_loss=0.0740 val_acc=0.9725
#   -> no improvement for 4/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=9.3s | total_elapsed=9.3s
#     [train] batch 40/267 | running_acc=1.0000 | this_chunk=12.0s | total_elapsed=21.3s
#     [train] batch 60/267 | running_acc=1.0000 | this_chunk=13.1s | total_elapsed=34.4s
#     [train] batch 80/267 | running_acc=0.9990 | this_chunk=12.2s | total_elapsed=46.6s
#     [train] batch 100/267 | running_acc=0.9992 | this_chunk=10.8s | total_elapsed=57.4s
#     [train] batch 120/267 | running_acc=0.9972 | this_chunk=8.7s | total_elapsed=66.1s
#     [train] batch 140/267 | running_acc=0.9958 | this_chunk=9.8s | total_elapsed=75.9s
#     [train] batch 160/267 | running_acc=0.9958 | this_chunk=9.9s | total_elapsed=85.8s
#     [train] batch 180/267 | running_acc=0.9954 | this_chunk=8.1s | total_elapsed=93.9s
#     [train] batch 200/267 | running_acc=0.9954 | this_chunk=9.7s | total_elapsed=103.7s
#     [train] batch 220/267 | running_acc=0.9955 | this_chunk=9.5s | total_elapsed=113.2s
#     [train] batch 240/267 | running_acc=0.9955 | this_chunk=8.1s | total_elapsed=121.3s
#     [train] batch 260/267 | running_acc=0.9952 | this_chunk=10.0s | total_elapsed=131.3s
#     [val] batch 20/34 | running_acc=0.9833 | this_chunk=6.1s | total_elapsed=6.1s
# [seed 7] Epoch 11/30 | train_loss=0.0126 train_acc=0.9953 | val_loss=0.1019 val_acc=0.9800
#   -> no improvement for 5/6 epochs
#     [train] batch 20/267 | running_acc=1.0000 | this_chunk=10.4s | total_elapsed=10.4s
#     [train] batch 40/267 | running_acc=0.9958 | this_chunk=12.0s | total_elapsed=22.4s
#     [train] batch 60/267 | running_acc=0.9972 | this_chunk=12.3s | total_elapsed=34.8s
#     [train] batch 80/267 | running_acc=0.9938 | this_chunk=12.2s | total_elapsed=47.0s
#     [train] batch 100/267 | running_acc=0.9950 | this_chunk=10.8s | total_elapsed=57.8s
#     [train] batch 120/267 | running_acc=0.9958 | this_chunk=9.8s | total_elapsed=67.6s
#     [train] batch 140/267 | running_acc=0.9964 | this_chunk=8.4s | total_elapsed=76.0s
#     [train] batch 160/267 | running_acc=0.9969 | this_chunk=9.5s | total_elapsed=85.5s
#     [train] batch 180/267 | running_acc=0.9972 | this_chunk=10.1s | total_elapsed=95.6s
#     [train] batch 200/267 | running_acc=0.9971 | this_chunk=8.0s | total_elapsed=103.6s
#     [train] batch 220/267 | running_acc=0.9973 | this_chunk=9.9s | total_elapsed=113.4s
#     [train] batch 240/267 | running_acc=0.9976 | this_chunk=9.7s | total_elapsed=123.1s
#     [train] batch 260/267 | running_acc=0.9978 | this_chunk=8.5s | total_elapsed=131.6s
#     [val] batch 20/34 | running_acc=0.9917 | this_chunk=5.9s | total_elapsed=5.9s
# [seed 7] Epoch 12/30 | train_loss=0.0073 train_acc=0.9978 | val_loss=0.0931 val_acc=0.9800
#   -> no improvement for 6/6 epochs
# Stopping early for seed 7: no improvement for 6 epochs.
# Finalized /content/drive/MyDrive/gastronet_experiments/hybrid_concat_v2/seed_7: removed latest.pt (best.pt + results.json verified present).
# Seed 7 done. test_acc=0.9800. latest.pt cleaned up.
#
#
# Seeds completed this run:
#   seed 42: test_accuracy=0.9775, best_val_acc=0.9825
#   seed 123: test_accuracy=0.9750, best_val_acc=0.9850
#   seed 7: test_accuracy=0.9800, best_val_acc=0.9800

# %%
cku.manifest_summary(MANIFEST_JSON_PATH)
# Out:
# _setup             seed_0      -> completed    acc=None account=acct_A notebook=NB0_setup_and_split_lock at 2026-09-07 10:15:46
# cnn_only           seed_7      -> completed    acc=0.985 account=acct_A notebook=NB1_cnn_only_baseline at 2026-09-06 12:56:38
# cnn_only           seed_42     -> resumed      acc=0.9825 account=acct_A notebook=NB1_cnn_only_baseline at 2026-09-06 12:26:57
# cnn_only           seed_123    -> completed    acc=0.9825 account=acct_A notebook=NB1_cnn_only_baseline at 2026-09-06 12:42:24
# cnn_only_v2        seed_7      -> completed    acc=0.9825 account=acct_A notebook=NB1_cnn_only_baseline at 2026-09-07 11:45:05
# cnn_only_v2        seed_42     -> completed    acc=0.985 account=acct_A notebook=NB1_cnn_only_baseline at 2026-09-07 11:01:48
# cnn_only_v2        seed_123    -> completed    acc=0.98 account=acct_A notebook=NB1_cnn_only_baseline at 2026-09-07 11:18:20
# hybrid_concat_v2   seed_7      -> completed    acc=0.98 account=acct_A notebook=NB3_hybrid_concat_baseline at 2026-09-09 20:04:01
# hybrid_concat_v2   seed_42     -> completed    acc=0.9825 account=acct_A notebook=NB3_hybrid_concat_baseline at 2026-09-09 19:09:36
# hybrid_concat_v2   seed_123    -> completed    acc=0.985 account=acct_A notebook=NB3_hybrid_concat_baseline at 2026-09-09 19:34:11
# hybrid_crossattn_v2 seed_7      -> completed    acc=0.9775 account=acct_A notebook=NB5_hybrid_crossattn_training at 2026-09-08 17:12:09
# hybrid_crossattn_v2 seed_42     -> completed    acc=0.98 account=acct_A notebook=NB5_hybrid_crossattn_training at 2026-09-08 16:10:59
# hybrid_crossattn_v2 seed_123    -> completed    acc=0.9725 account=acct_A notebook=NB5_hybrid_crossattn_training at 2026-09-08 16:32:30
# vit_only_v2        seed_7      -> completed    acc=0.9675 account=acct_A notebook=NB2_vit_only_baseline at 2026-09-07 12:36:00
# vit_only_v2        seed_42     -> completed    acc=0.97 account=acct_A notebook=NB2_vit_only_baseline at 2026-09-07 12:19:48
# vit_only_v2        seed_123    -> completed    acc=0.9625 account=acct_A notebook=NB2_vit_only_baseline at 2026-09-07 12:25:10

# %%
import numpy as np
import glob

def load_seed_results(model_family):
    results = []
    for rf in sorted(glob.glob(os.path.join(EXPERIMENTS_ROOT, model_family, "seed_*", "results.json"))):
        with open(rf) as f:
            results.append(json.load(f))
    return results

for family in ["cnn_only_v2", "vit_only_v2", MODEL_FAMILY]:
    results = load_seed_results(family)
    if not results:
        print(f"{family}: no results found yet")
        continue
    accs = [r["test_accuracy"] for r in results]
    seeds = [r["seed"] for r in results]
    if len(accs) > 1:
        print(f"{family:20s} seeds={seeds} mean={np.mean(accs):.4f} std={np.std(accs, ddof=1):.4f}")
    else:
        print(f"{family:20s} seeds={seeds} (only one seed so far) acc={accs[0]:.4f}")
# Out:
# cnn_only_v2          seeds=[123, 42, 7] mean=0.9800 std=0.0025
# vit_only_v2          seeds=[123, 42, 7] mean=0.9717 std=0.0088
# hybrid_concat_v2     seeds=[123, 42, 7] mean=0.9775 std=0.0025

# %% [markdown]
# ## After this notebook finishes
#
# 1. **Memory**: `BATCH_SIZE=12` here (vs 16 in NB1/NB2) because this model
#    holds two backbones and two image tensors per sample simultaneously. If
#    you hit CUDA OOM, drop to 8.
# 2. **Expected outcome, honestly**: this model may land close to, above, or
#    below both `cnn_only_v2` and `vit_only_v2` -- concatenation fusion isn't
#    expected to reliably beat a strong single backbone on a near-saturated
#    dataset. Don't be surprised either way. What matters is having this
#    number as the reference point for `hybrid_crossattn` later.
# 3. **Overfitting**: watch the same train/val gap pattern seen in NB1 --
#    early stopping (`PATIENCE=6`) should catch it, but glance at
#    `history.json` per seed regardless.
# 4. **Comparison cell** (second to last): prints mean±std for `cnn_only_v2`,
#    `vit_only_v2`, and `hybrid_concat_v2` side by side, so you can see where
#    this baseline actually lands relative to the single-branch models the
#    moment all three have results.
# 5. **Next: NB4** -- `hybrid_crossattn` model definition + a dummy-tensor
#    shape/forward-pass sanity check (no real training yet), implementing the
#    architectural decisions from the project handoff doc Section 2:
#    unidirectional cross-attention (CNN tokens as queries attending to
#    ViT-Small keys/values), learned 2D positional embedding on CNN spatial
#    tokens, `d_model=256` fusion block, content-only queries. This notebook's
#    dual-resolution dataset pattern (`GastroDualDataset`) carries over
#    directly into NB4/NB5's data pipeline.
